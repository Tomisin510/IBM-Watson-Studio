# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **My Name is Tomisin Obijole**  <br>  I desire to be an experienced Data Scientist

# %% [markdown]
# *I am Interested in Data Science because I know there's loads of Big data in several fields that I have invested interest in, like Geosciences for example, which has a lot of unstructured, Big Data*

# %% [markdown]
# ### My code is written out to do basic arithmetic solving.

# %%
(25 * 25) / (16 + 9)
# Out:
# 25.0

# %% [markdown]
# There will be ah horizontal rule after this sentence
# ___
#
# 1. open the file containing the linux mascot.
# 2. Marvel at its beauty.
#
#     ![Tux, the Linux mascot](https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Tux_Enhanced.svg/154px-Tux_Enhanced.svg.png)
#
# 3. Close the file
# 4. Below are the Allotropes of Carbon in a bulleted list
# * Diamond
# * Graphite
# <br>
# ~~They have the same chemical composition~~
